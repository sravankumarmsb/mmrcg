# %%
import os
import torch
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import zipfile
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

import logging
from tqdm import tqdm
import pandas as pd
import json
from collections import defaultdict
import shutil

# %%
import kagglehub
kaggle_flickr30k_dataset_path = kagglehub.dataset_download("adityajn105/flickr30k")
print('Data source import complete.')
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.8).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/adityajn105/flickr30k?dataset_version_number=1...
# 100%|██████████| 8.16G/8.16G [01:10<00:00, 125MB/s]
# Extracting files...
# Data source import complete.

# %%
#  to copy flickr8k_images
# Define source and destination paths
source_images_path = kaggle_flickr30k_dataset_path + "/Images"  # Replace with actual path
images_path = "/content/flickr30k_dataset/flickr30k_images" # Replace with your desired destination

# Check if the destination directory exists, if not create it
if not os.path.exists(images_path):
    os.makedirs(images_path)

# Copy the folder recursively
shutil.copytree(source_images_path, images_path, dirs_exist_ok=True)

print(f"Successfully copied flickr8k_images to {images_path}")
# Out:
# Successfully copied flickr8k_images to /content/flickr30k_dataset/flickr30k_images

# %%
print(f"Length of image directory: {len(os.listdir(images_path))}")
# Out:
# Length of image directory: 31785

# %%
source_captions_path = kaggle_flickr30k_dataset_path + "/captions.txt"  # Replace with actual path
destination_captions_path = "/content/flickr30k_dataset" # Replace with your desired destination


# Check if the destination directory exists, if not create it
if not os.path.exists(destination_captions_path):
    os.makedirs(destination_captions_path)
shutil.copy(source_captions_path, destination_captions_path)

print(f"Successfully copied captions to {destination_captions_path}")
# Out:
# Successfully copied captions to /content/flickr30k_dataset

# %%
#python
df = pd.read_csv("/content/flickr30k_dataset/captions.txt", delimiter=",")
df.columns = ['image', 'caption']
# 1. Add 'caption_number' and 'id' columns
df['caption_number'] = 0  # Initialize with 0
df['id'] = 0  # Initialize with 0
# 2. Assign unique 'id' to each unique image
unique_images = df['image'].unique()
image_id_mapping = {image: idx for idx, image in enumerate(unique_images)}
df['id'] = df['image'].map(image_id_mapping)
# 3. Assign occurrence numbers to 'caption_number'
df['caption_number'] = df.groupby('image').cumcount()
new_order = ['image','caption','caption_number','id']
df = df[new_order]
df = df.dropna()
df.to_csv("/content/flickr30k_dataset/captions.csv", index=False)
df.head()
# Out:
#             image                                            caption  \
# 0  1000092795.jpg   Two young guys with shaggy hair look at their...
# 1  1000092795.jpg   Two young , White males are outside near many...
# 2  1000092795.jpg   Two men in green shirts are standing in a yard .
# 3  1000092795.jpg       A man in a blue shirt standing in a garden .
# 4  1000092795.jpg            Two friends enjoy time spent together .
#
#    caption_number  id
# 0               0   0
# 1               1   0
# 2               2   0
# 3               3   0
# 4               4   0

# %%
# Paths
images_path = "/content/flickr30k_dataset/flickr30k_images"  # Path to images
captions_file = "/content/flickr30k_dataset/captions.txt"  # Path to captions file
images_embeddings_file = "/content/flickr30k_dataset/30k_pretrain_image_embeddings.pt"
captions_embeddings_file = "/content/flickr30k_dataset/30k_pretrain_caption_embeddings.pt"

# %%
def setup_logging(log_directory="/content/flickr30k_dataset/", log_file="mmrcs30k.log"):
    """
    Set up logging configuration with both console and file handlers.
    Args:
        log_directory (str): Directory where the log file will be saved.
        log_file (str): The name of the log file.
    Returns:
        logger: Configured logger object.
    """
    # Ensure the log directory exists
    if not os.path.exists(log_directory):
        os.makedirs(log_directory)

    # Full log file path
    log_path = os.path.join(log_directory, log_file)
    # Create a custom logger
    logger = logging.getLogger()
    # First, remove all existing handlers to avoid duplication
    for handler in logger.handlers[:]:
        logger.removeHandler(handler)
    # Set the logging level to INFO
    logger.setLevel(logging.INFO)
    # Create handlers for file and console output
    file_handler = logging.FileHandler(log_path)
    console_handler = logging.StreamHandler()
    # Set the log level for handlers
    file_handler.setLevel(logging.INFO)
    console_handler.setLevel(logging.INFO)
    # Create a formatter and set it for both handlers
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    # Add handlers to the logger
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    return logger
logger = setup_logging()

# %%
#!rm -rf /content/flixke8k_dataset

# %%
# Load the pre-trained CLIP model and processor
device = "cuda" if torch.cuda.is_available() else "cpu"
logger.info(device)
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# 2025-02-14 09:49:56,874 - INFO - cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
#!unzip /content/mmrcs-main.zip -d /content/
# Out:
# Archive:  /content/mmrcs-main.zip
# dafaf2b3e1cee896126879a3100b29a935e54c5f
#    creating: /content/mmrcs-main/
#    creating: /content/mmrcs-main/flickr1k_dataset/
#    creating: /content/mmrcs-main/flickr1k_dataset/Images/
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1000268201_693b08cb0e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1001773457_577c3a7d70.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1002674143_1b742ab4b8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1003163366_44323f5815.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1007129816_e794419615.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1007320043_627395c3d8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1009434119_febe49276a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1012212859_01547e3f17.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1015118661_980735411b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1015584366_dfcec3c85a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/101654506_8eb26cfb60.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/101669240_b2d3e7f17b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1016887272_03199f49c4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1019077836_6fc9b15408.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1019604187_d087bf9a5f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1020651753_06077ec457.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1022454332_6af2c1449a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1022454428_b6b660a67b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1022975728_75515238d8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/102351840_323e3de834.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1024138940_f1fefbdce1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/102455176_5f8ead62d5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1026685415_0431cbf574.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1028205764_7e8df9a2ea.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1030985833_b0902ea560.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/103106960_e8a41d64f8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/103195344_5d2dc613a3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/103205630_682ca7285b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1032122270_ea6f0beedb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1032460886_4a598ed535.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1034276567_49bb87c51c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/104136873_5b5d41be75.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1042020065_fb3d3ba5ba.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1042590306_95dea0916c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1045521051_108ebc19be.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1048710776_bb5b0a5c7c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1052358063_eae6744153.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/105342180_4d4a40b47f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1053804096_ad278b25f1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1055623002_8195a43714.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1055753357_4fa3d8d693.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1056249424_ef2a2e041c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1056338697_4f7d7ce270.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1056359656_662cee0814.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1056873310_49c665eb22.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1057089366_ca83da0877.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1057210460_09c6f4c6c1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1057251835_6ded4ada9c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/106490881_5a2dd9b7bd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/106514190_bae200f463.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1067180831_a59dc64344.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1067675215_7336a694d6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1067790824_f3cc97239b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1072153132_53d2bb1b60.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/107318069_e9f2ef32de.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1075716537_62105738b4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/107582366_d86f2d3347.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1075867198_27ca2e7efe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1075881101_d55c46bece.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1077546505_a4f6c4daa9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1077931201_1e0bb83105.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1079274291_9aaf896cc1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/10815824_2997e03d76.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1082252566_8c79beef93.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1082379191_ec1e53f996.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1084040636_97d9633581.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1084104085_3b06223afe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1087168168_70280d024a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1087539207_9f77ab3aaf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1088767354_2acee738cf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/108898978_7713be88fc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/108899015_bf36131a57.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1089181217_ee1167f7af.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1089755335_0bfbfd30e6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109202756_b97fcdc62c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109202801_c6381eef15.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/109260216_85b0be5378.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109260218_fca831f933.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1093716555_801aacef79.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1093737381_b313cd49ff.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1094462889_f9966dafa6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1095476286_87d4f8664e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1095580424_76f0aa8a3e.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1095590286_c654f7e5a9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1095980313_3c94799968.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1096097967_ac305887b4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1096165011_cc5eb16aa6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1096395242_fc69f0ae5a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109671650_f7bbc297fa.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109738763_90541ef30d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109738916_236dc456ac.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109823394_83fcb735e1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109823395_6fb423a90f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/109823397_e35154645f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1100214449_d10861e633.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1104133405_c04a00707f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1105959054_9c3a738096.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/110595925_f3395c8bd6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1107246521_d16a476380.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1107471216_4336c9b328.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1110208841_5bb6806afe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1112212364_0c48235fc2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/111497985_38e9f88856.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/111537217_082a4ba060.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/111537222_07e56d5a30.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1115565519_d976d4b1f1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1115679311_245eff2f4b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/111766423_4522d36e56.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1117972841_2b9261f95f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1118557877_736f339752.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1119015538_e8e796281e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1119418776_58e4b93eac.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1119463452_69d4eecd08.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1121416483_c7902d0d49.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/112178718_87270d9b4d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/112243673_fd68255217.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1122944218_8eb3607403.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1124448967_2221af8dc5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1129704496_4a61441f2c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1130017585_1a219257ac.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1130369873_d80a1aa59c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1130401779_8c30182e3e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1131155939_b4b457b05e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1131340021_83f46b150a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1131800850_89c7ffd477.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1131804997_177c3c0640.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1131932671_c8d17751b3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1132772170_600610c5df.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/113678030_87a6a6e42e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1138784872_69ade3f2ab.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/114051287_dd85625a04.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1141718391_24164bf1b1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1141739219_2c47195e4c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1142283988_6b227c5231.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1142847777_2a0c1c2551.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1143373711_2e90b7b799.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1143882946_1898d2eeb9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1144288288_e5c9558b6a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1148238960_f8cacec2fc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1149179852_acad4d7300.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/114949897_490ca7eaec.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1151466868_3bc4d9580b.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1153704539_542f7aa3a5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1155138244_859fd6e079.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/115684808_cb01227802.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1159574340_99ba8c3c59.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1160034462_16b38174fe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1160441615_fe6b3c5277.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1163282319_b729b24c46.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/116409198_0fe0c94f3b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1164131282_b30926f332.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1164765687_7aca07bbe7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1167662968_e466f1e80a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1167669558_87a8a467d6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1167908324_8caab45e15.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1169307342_e7a4685a5c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1174525839_7c1e6cfa86.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1174629344_a2e1a2bdbf.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1176580356_9810d877bf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1177994172_10d143cb8d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1178705300_c224d9a4f1.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/118187095_d422383c81.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/118309463_a532b75be9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1184967930_9e29ce380d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1187435567_18173c148b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1187593464_ce862352c6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1189977786_4f5aaed773.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1191338263_a4fa073154.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1193116658_c0161c35b5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/119534510_d52b3781a3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1197800988_7fb0ca4888.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1198194316_543cc7b945.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1204996216_71d7519d9a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1206506157_c7956accd5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1207159468_425b902bfb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1211015912_9f3ee3a995.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1213336750_2269b51397.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1215334959_b1970965f7.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/121800200_bef08fae5f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/121971540_0a986ee176.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1220401002_3f44b1f3f7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1222322358_225067636e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1224851143_33bcdd299c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1225443522_1633e7121f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1227655020_b11a1bb112.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1229756013_94663527d7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1231229740_8dcbf80bfb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1232148178_4f45cc3284.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1234293791_6566284bcd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1234817607_924893f6e1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1235580648_7eebaed9bc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1235681222_819231767a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1235685934_be89b231fb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1236951314_0308dc4138.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1236964638_1808784a3c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1237985362_dbafc59280.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/123889082_d3751e0350.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/123997871_6a9ca987b1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1240297429_c36ae0c58f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/124195430_d14028660f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1244140539_da4804d828.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1244306891_8e78ae1620.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1244485675_822e6efe60.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1245022983_fb329886dd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1247181182_35cabd76f3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1248357227_2b4175fc39.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1248734482_3038218f3b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/124881487_36e668145d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1248940539_46d33ed487.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1248953128_24c9f8d924.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/124972799_de706b6d0b.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1251558317_4ef844b775.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1252396628_eb81d3905b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1252787177_4b08625897.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/125319704_49ead3463c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1253264731_e7c689eca5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1253275679_e955fb7304.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1255504166_f2437febcb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1258913059_07c613f7ff.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1259936608_e3f0064f23.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1260816604_570fc35836.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1262077938_8b9516c273.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1262454669_f1caafec2d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1262583859_653f1469a9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1263126002_881ebd7ac9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1263801010_5c74bf1715.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1267711451_e2a754b4f8.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1269470943_ba7fc49b4d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1271210445_7f7ecf3791.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1271960365_e54033f883.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1273001772_1585562051.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/127450902_533ceeddfc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/127488876_f2d2a89588.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/127490019_7c5c08cb11.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1277185009_06478dd457.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1277743944_f4e8c78403.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1280147517_98767ca3b3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1280320287_b2a4b9b7bd.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1282392036_5a0328eb86.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/12830823_87d2654e31.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1285067106_2adc307240.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1285874746_486731a954.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1286408831_05282582ed.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1287064529_aa4e4f3c31.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1287073593_f3d2a62455.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1287475186_2dee85f1a5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1287920676_d21a0b289b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1287931016_fb015e2e10.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1287982439_6578006e22.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1288909046_d2b2b62607.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/128912885_8350d277a4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1289142574_2bd6a082dd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1290894194_8a4ffdc7eb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1294578091_2ad02fea91.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1295669416_21cabf594d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1295671216_cde1b9c9d1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1295698260_e10c53c137.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/129599450_cab4e77343.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1296412797_85b6d2f8d6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1296770308_3db2022f5a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1298295313_db1f4c6522.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1298866571_b4c496b71c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1299459550_1fd5594fa2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1299459562_ed0e064aee.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1301140633_046e4e8010.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/130211457_be3f6b335d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1302657647_46b36c0d66.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1303335399_b3facd47ab.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1303548017_47de590273.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1303550623_cb43ac044a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1303727066_23d0f6ed43.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1303727828_d1052ee341.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1304100320_c8990a1539.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1304961697_76b86b0c18.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1305564994_00513f9a5b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1306145560_1e37081b91.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1307635496_94442dc21a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1308472581_9961782889.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1308617539_54e1a3dfbe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1309330801_aeeb23f1ee.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1311132744_5ffd03f831.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1311388430_4ab0cd1a1f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1312020846_5abb4a9be2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1312227131_771b5ed201.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1312954382_cf6d70d63a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1313693129_71d0b21c63.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1313961775_824b87d155.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1316247213_1d2c726dd5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/131632409_4de0d4e710.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1317292658_ba29330a0b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1319634306_816f21677f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1321723162_9d4c78b8af.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1321949151_77b77b4617.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1322323208_c7ecb742c6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1324816249_86600a6759.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/132489044_3be606baf7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1329832826_432538d331.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1330645772_24f831ff8f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/133189853_811de6ab2a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1332208215_fa824f6659.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1332492622_8c66992b62.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1332722096_1e3de8ae70.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1332815795_8eea44375e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1332823164_c70a5d930e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1333888922_26f15c18c3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1334892555_1beff092c3.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1335617803_4fbc03dab0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1337792872_d01a390b33.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1338523142_57fce8229b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/133905560_9d012b47f3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1339596997_8ac29c1841.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1341787777_4f1ebb1793.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1342766791_1e72f92455.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1342780478_bacc32344d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1343426964_cde3fb54e8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1346051107_9cdc14e070.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1346529555_e916816cfe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/134724228_30408cd77f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1347519824_e402241e4f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1348113612_5bfc5f429e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1348304997_afe60a61df.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1348891916_ebd4413033.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/134894450_dadea45d65.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1348947380_14f0fc1237.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1348957576_c4a78eb974.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1350811702_2ce7cfd0c5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1350948838_fdebe4ff65.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1351315701_6580b51c41.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1351764581_4d4fb1b40f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/135235570_5698072cd4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1352398363_9cc8ffcce9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1352410176_af6b139734.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1354318519_2f9baed754.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1355450069_c0675b0706.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1355703632_5683a4b6fb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1355833561_9c43073eda.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1355935187_2c99648138.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1355945307_f9e01a9a05.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1356543628_c13ebe38fb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1356796100_b265479721.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1357689954_72588dfdc4.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1357724865_4faf4e1418.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1357753846_6185e26040.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1358089136_976e3d2e30.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1358892595_7a37c45788.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1359101233_16c2c150e3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1361420539_e9599c60ae.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1362128028_8422d53dc4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1363843090_9425d93064.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1363924449_487f0733df.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/136552115_6dc3e7231c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/136639119_6040b00946.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/136644343_0e2b423829.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/136644885_f7d2bbf546.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1368338041_6b4077ca98.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1368383637_614646cc4a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/136886677_6026c622eb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1370615506_2b96105ca3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1370773415_967b1ffde1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1377668044_36398401dd.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1378557186_4bd1da6834.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1379026456_153fd8b51b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1383698008_8ac53ed7ec.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1383840121_c092110917.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1384292980_4022a7520c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1386251841_5f384a0fea.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1386964743_9e80d96b05.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/138705546_be7a6845dd.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/138718600_f430ebca17.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1387443857_602ab6f9bf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1387461595_2fe6925f73.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1387785218_cee67735f5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1388346434_524d0b6dfa.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1388373425_3c72b56639.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1388970365_162edcceb4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1389264266_8170bc1c54.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1389323170_d1c81d6b51.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1389651420_8d95d8f6ed.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1390268323_2c8204e91c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1392272228_cf104086e6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1394368714_3bc7c19969.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1394396709_65040d97ab.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1394599090_fe0ba238f0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1394620454_bf708cc501.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1394927474_0afdd82fc4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1396064003_3fd949c9dd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1396703063_e8c3687afe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1397295388_8a5b6b525d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1397887419_e798697b93.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1397923690_d3bf1f799e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1398606571_f543f7698a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1398613231_18de248606.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1398873613_7e3174dd6c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1400424834_1c76e700c4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1401961581_76921a75c5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1402640441_81978e32a9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1402641725_5e027ecaa7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1402843760_d30f1dbf0f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1402859872_0fc8cf8108.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1403414927_5f80281505.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/140377584_12bdbdf2f8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/140430106_2978fda105.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1404832008_68e432665b.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1405221276_21634dcd58.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/140526326_da07305c1c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/140526327_3cb984de09.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1406010299_5755339f08.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1408958345_68eea9a4e4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1410193619_13fff6c875.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/141139674_246c0f90a1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/141140165_9002a04f19.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1412832223_99e8b4701a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1413956047_c826f90c8b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1414779054_31946f9dfc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1414820925_3504c394e1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1415591512_a84644750c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1417031097_ab656bc4bd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1417295167_5299df6db8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/141755290_4b954529f3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/141755292_7a0b3364cf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1417637704_572b4d6557.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1417882092_c94c251eb3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1417941060_2a0f7908bc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1418019748_51c7d59c11.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1418266617_b32143275b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1418503947_953d373632.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1419286010_b59af3962a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1419385780_1383ec7ba9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1420060020_7a6984e2ea.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1420060118_aed262d606.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1423126855_6cd2a3956c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1423997242_ea2189ec5e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1424237335_b3be9920ba.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1424775129_ffea9c13ab.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1425013325_bff69bc9da.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1425069308_488e5fcf9d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1425069590_570cc7c2d8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1425485485_d7c97a5470.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1425919702_ddb761aeec.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1426014905_da60d72957.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1427391496_ea512cbe7f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/142802798_962a4ec5ce.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1428578577_82864facae.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1428641354_f7453afbea.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1428681303_04213524e3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1429546659_44cb09cbe2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1429723917_6af585e4c0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1429814475_0b592b9995.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1430154945_71bbaa094a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1432179046_8e3d75cf81.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1432342377_3e41603f26.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143237785_93f81b3201.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1433088025_bce2cb69f8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1433142189_cda8652603.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1433397131_8634fa6664.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1433577867_39a1510c43.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1434005938_ad75c8598c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1434607942_da5432c28c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143552697_af27e9acf5.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/143552829_72b6ba49d4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1436760519_8d6101a0ed.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143680442_2f03f76944.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143680966_0010ff8c60.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143684568_3c59299bae.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143688205_630813a466.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143688283_a96ded20f1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/143688895_e837c3bc76.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1439046601_cf110a75a7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1439282131_3814d6ae04.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1440024115_129212c988.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1443807993_aebfb2784a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1445123245_c7b9db0e0c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1445754124_647168f211.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1446053356_a924b4893f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1446933195_8fe9725d62.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1448511770_1a4a9c453b.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1449370354_380c4123c9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1449625950_fc9a8d02d9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1449692616_60507875fb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1452361926_6d8c535e32.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1453366750_6e8cf601bf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1454678644_7e5a371301.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1454841725_4b6e6199e2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1456393634_74022d9056.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1456630952_dd4778a48f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/145721496_687af9bb18.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/145721498_a27d2db576.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1457762320_7fe121b285.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1459032057_97e73ed6ab.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1459250022_bf1eddad11.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1460352062_d64fb633e0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1460500597_866fa0c6f3.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/146098876_0d99d7fb98.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/146100443_906d87faa2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1461329041_c623b06e5b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1461653394_8ab96aae63.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1461667284_041c8a2475.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1463638541_c02cfa04dc.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1463732130_a754441289.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1463732807_0cdf4f22c7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1464120327_d90279ca3a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1465666502_de289b3b9c.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/146577645_91b570c0d0.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/146577646_9e64b8c2dc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1466307485_5e6743332e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1466307489_cb8a74de09.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1466479163_439db855af.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1467533293_a2656cc000.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1468103286_96a6e07029.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1468389504_c724bdcad0.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1468429623_f001988691.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1468962616_5803b4397f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1469000260_5d473c8283.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1469358746_2a879abaf3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1470061031_4cb59c12a8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1470132731_fa416b7504.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1470536919_1f3fd6c65a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1472053993_bed67a3ba7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1472230829_803818a383.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1472249944_d887c3aeda.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1472653060_7427d2865a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1472882567_33dc14c8b6.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1473080948_bae2925dc8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1473250020_dc829a090f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1473618073_7db56a5237.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1474474514_b3eb492722.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1475046848_831245fc64.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1476002408_4256b7b2fa.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1476241331_2f43b67aed.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1478268555_7e301fc510.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1478294229_7e1c822fea.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1478606153_a7163bf899.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1479028910_3dab3448c8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1479124077_17dcc0d5d7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1479513774_70c94cf9d3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1479679558_d0a01bc62b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1479857177_9d4a6f38fd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1480712062_32a61ad4b7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1481062342_d9e34366c4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1482960952_95f2d419cb.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/148512773_bae6901fd6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1488937076_5baa73fc2a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1489286545_8df476fa26.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1490213660_9ea45550cf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1490670858_e122df2560.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1491192153_7c395991e5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1499495021_d295ce577c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1499554025_a8ffe0e479.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1499581619_a5f65a882c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1500853305_0150615ce9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1501297480_8db52c15b0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1501811302_5e723fc529.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1501985304_8c50093004.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/150387174_24825cf871.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1505686764_9e3bcd854a.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/150582765_bad8dec237.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1507563902_6ec8d5d822.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1508269285_6c5723f67d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1509786421_f03158adfc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1510078253_96e9ec50e7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1510669311_75330b4781.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1511807116_41c3645e8c.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/1514957266_a19827c538.jpg
# ...
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1982852140_56425fa7a2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1984936420_3f3102132b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1989145280_3b54452188.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1991806812_065f747689.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1994416869_4dd769a806.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/199463720_329a802206.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/199809190_e3f6bbe2bc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1998255400_0cd086908f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1998457059_c9ac9a1e1a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/1999444757_1b92efb590.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2000459828_3c9e109106.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2003663004_5b70920a98.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2004674713_2883e63c67.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/200771289_31902164a7.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2009636597_e3f4fe19fb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/201682811_105241dee3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2017276266_566656c59d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2021602343_03023e1fd1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2021613437_d99731f986.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2021671653_567395c7cf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2029280005_a19609c81a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2030781555_b7ff7be28f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/203114209_e4cd71a6b7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2034553054_b00c166895.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2036407732_d5a0389bba.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2038662925_f4fa8c2534.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2039457436_fc30f5e1ce.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2040941056_7f5fd50794.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2041867793_552819a40b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2042009399_afad34e7c1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2043427251_83b746da8e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2043520315_4a2c782c90.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2044063458_fcc76a7636.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2045023435_181854c013.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2045109977_b00ec93491.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2045562030_654ddea5e5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2045928594_92510c1c2a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2046222127_a6f300e202.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2046778775_0dd7cac6ab.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2049051050_20359a434a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2049646140_d0de01e3c4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2050067751_22d2763fd2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2051194177_fbeee211e3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2052202553_373dad145b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2052702658_da1204f6d1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2052953131_30834196fb.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2053006423_6adf69ca67.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2053441349_a98b5fc742.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2053733930_e245615ad4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2053777548_108e54c826.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2054308369_f9c6ec7815.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2054869561_ff723e9eab.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2055646179_169807fed4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2056041678_d6b5b39b26.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2056042552_f59e338533.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2056377805_e9a9b3bcf0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/205682549_713aa6cd88.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2056930414_d2b0f1395a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2057160636_6e9cf3b5f0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2057305043_952b8dc82c.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2057306459_2f52ce648e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2058091220_2087270068.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2058124718_89822bc96e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2058472558_7dd5014abd.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2059616165_b7c99c1009.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2059842472_f4fb61ea08.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2060031241_a3ae7a06bb.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/206087108_d4557d38ee.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2061144717_5b3a1864f0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2061354254_faa5bd294b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2061397486_53a61e17c5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2061927950_dafba5b8a3.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2061944672_0383e65c8a.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2062607137_dac194ad02.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2063277300_f7ff476914.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2064417101_3b9d817f4a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2064780645_8f28a1529f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2064790732_219e52e19c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2064792226_97e41d8167.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2065309381_705b774f51.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2065875490_a46b58c12b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2066048248_f53f5ef5e2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2066241589_b80e9f676c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2066271441_1f1f056c01.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2067362863_59577f9d4d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2067833088_04e84e5bf2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2068403258_2669cf9763.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2068465241_3bcabacfd7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2068960566_21e85ae0dc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2069279767_fb32bfb2de.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2070798293_6b9405e04d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2070831281_dc04b3e15d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2070831523_5035d5537e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2071309418_1d7580b0f0.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/207237775_fa0a15c6fe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2072574835_febf0c5fb9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/207275121_ee4dfa0bf2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2073105823_6dacade004.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2073174497_18b779999c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2073756099_7e02c0110c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2073964624_52da3a0fc4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2074146683_7c83167aa1.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2074244690_82e30ff44b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2074764331_90a9962b52.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2075041394_0b3ea1822d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2075321027_c8fcbaf581.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2075493556_b763648389.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/207584893_63e73c5c28.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2076428547_738e0a132f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2076865206_53918c820c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2076906555_c20dc082db.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2077079696_03380d218b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/207731022_988f6afb35.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2077346067_0a3a5aae65.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2078311270_f01c9eaf4c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2079110798_ad1370a646.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2079152458_40712c3b40.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/207930963_af3a2f1784.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2079554580_f18d5c181b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2080033499_6be742f483.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2081141788_38fa84ce3c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2081446176_f97dc76951.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2081615901_13092cac56.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2081679622_6f1442367d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2082005167_a0d6a70020.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2083434441_a93bc6306b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2083778090_3aecaa11cc.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2084103826_ffd76b1e3e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2084157130_f288e492e4.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2084217208_7bd9bc85e5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2085078076_b9db242d21.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2085255128_61224cc47f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2085400856_ae09df33a7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2085403342_a17b0654fe.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2085557551_7a88d01d4e.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2085726719_a57a75dbe5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2086513494_dbbcb583e7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2086532897_b8714f2237.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2086534745_1e4ab80078.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2086678529_b3301c2d71.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2087317114_cf06df5aa5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2087640654_1a84577a44.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2088120475_d6318364f5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2088460083_42ee8a595a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2088532947_c628e44c4a.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2088910854_c6f8d4f5f9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2089122314_40d5739aef.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2089350172_dc2cf9fcf6.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2089426086_7acc98a3a8.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2089442007_6fc798548c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2089539651_9e518ec7de.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2089542487_b4c1ee7025.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2089555297_95cf001fa7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2090327868_9f99e2740d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2090339522_d30d2436f9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2090386465_b6ebb7df2c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2090387793_274ab4cf7d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2090545563_a4e66ec76b.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2090723611_318031cfa5.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2090997177_76d482b158.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2091171488_c8512fec76.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2092177624_13ab757e8b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2092419948_eea8001d0f.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2092870249_90e3f1855b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2094323311_27d58b1513.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2094543127_46d2f1fedf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2094810449_f8df9dcdf7.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2095007523_591f255708.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2095078658_c14ba89bc2.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2095435987_1b7591d214.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2095444126_201ff9f222.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2095478050_736c4d2d28.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/209605542_ca9cc52e7b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2096771662_984441d20d.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2097398349_ff178b3f1b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2097403787_77a154f5b9.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2097407245_c798e0dcaf.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2097420505_439f63c863.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2097489021_ca1b9f5c3b.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2098174172_e57d86ea03.jpg
#  extracting: /content/mmrcs-main/flickr1k_dataset/Images/2098418613_85a0c9afea.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2098646162_e3b3bbf14c.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2099323664_bb20457f26.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2100046085_69b59b6645.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2100735137_05c6079537.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/Images/2100816230_ff866fb352.jpg
#   inflating: /content/mmrcs-main/flickr1k_dataset/captions.txt
#    creating: /content/mmrcs-main/flickr1k_dataset/model_data/
#  extracting: /content/mmrcs-main/flickr1k_dataset/model_data/test.txt

# %%
def preprocess_and_save_image_embeddings(images_path, images_embeddings_file, processor, model, device, batch_size=16):
    """
    Preprocess images, generate embeddings, and save all in a single file.

    Args:
        images_path (str): Path to the directory containing image files.
        images_embeddings_file (str): Path to save the combined embeddings file.
        processor: Pretrained image processor (e.g., CLIPProcessor).
        model: Pretrained model to generate image embeddings (e.g., CLIPModel).
        device (str): Device to perform computation on ('cuda' or 'cpu').
        batch_size (int): Number of images to process in a batch.
    """
    image_files = [f for f in os.listdir(images_path) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

    if not image_files:
        logger.warning("No image files found in the specified directory.")
        return

    all_embeddings = []
    image_filenames = []

    for i in tqdm(range(0, len(image_files), batch_size), desc="Processing Images"):
        batch_files = image_files[i:i+batch_size]

        try:
            images = [Image.open(os.path.join(images_path, img)).convert("RGB") for img in batch_files]
            inputs = processor(images=images, return_tensors="pt", padding=True).to(device)

            with torch.no_grad():
                embeddings = model.get_image_features(**inputs)
                embeddings = embeddings / embeddings.norm(dim=-1, keepdim=True)  # Normalize

            all_embeddings.append(embeddings.cpu())
            image_filenames.extend(batch_files)

        except Exception as e:
            logger.error(f"Error processing batch {i // batch_size + 1}: {e}")

    # Save all embeddings in one file
    torch.save(torch.cat(all_embeddings), images_embeddings_file)

    # Save filenames mapping
    with open(images_embeddings_file.replace('.pt', '_filenames.json'), 'w') as f:
        json.dump(image_filenames, f)

    logger.info(f"All image embeddings saved in: {images_embeddings_file}")

# %%
preprocess_and_save_image_embeddings(images_path, images_embeddings_file, processor, model, device)
# Out:
# Processing Images: 100%|██████████| 1987/1987 [05:24<00:00,  6.13it/s]
# 2025-02-14 09:55:47,232 - INFO - All image embeddings saved in: /content/flickr30k_dataset/30k_pretrain_image_embeddings.pt

# %%
def load_captions(df):
    df["image"] = df["image"].str.strip()
    df["caption"] = df["caption"].str.strip()
    captions_dict = defaultdict(list)  # Dictionary to store image -> list of captions
    for _, row in df.iterrows():
        image_name = row["image"]
        caption_text = row["caption"]
        captions_dict[image_name].append(caption_text)  # Store caption under the image

    return captions_dict  # Return a dictionary, not a list

# %%
dataframe = pd.read_csv("/content/flickr30k_dataset/captions.csv")
captions = load_captions(df)

# %%
def preprocess_and_save_caption_embeddings(captions, captions_embeddings_file, processor, model, device, batch_size=16):
    """
    Generate and save text embeddings in a single file.

    Args:
        captions (dict): Dictionary with image names as keys and lists of captions as values.
        captions_embeddings_file (str): Path to save the combined embeddings file.
        processor: The text processor for tokenizing captions.
        model: The model used for generating text embeddings.
        device: The device (CPU or GPU) to use for computation.
        batch_size (int): Number of captions to process in a batch.
    """
    all_captions = []
    caption_filenames = []

    for image_name, caption_list in captions.items():
        for i, caption in enumerate(caption_list, start=1):
            all_captions.append(caption)
            caption_filenames.append(f"{image_name}_{i}")

    all_embeddings = []

    for start in tqdm(range(0, len(all_captions), batch_size), desc="Processing Captions"):
        end = start + batch_size
        batch_captions = all_captions[start:end]

        try:
            inputs = processor(text=batch_captions, return_tensors="pt", padding=True, truncation=True, max_length=77).to(device)

            with torch.no_grad():
                text_features = model.get_text_features(**inputs)
                text_features = text_features / text_features.norm(p=2, dim=-1, keepdim=True)

            all_embeddings.append(text_features.cpu())

        except Exception as e:
            logger.error(f"Error processing batch {start}-{end}: {e}")

    # Save all embeddings in one file
    torch.save(torch.cat(all_embeddings), captions_embeddings_file)

    # Save filenames mapping
    with open(captions_embeddings_file.replace('.pt', '_filenames.json'), 'w') as f:
        json.dump(caption_filenames, f)

    logger.info(f"All caption embeddings saved in: {captions_embeddings_file}")

# %%
preprocess_and_save_caption_embeddings(captions, captions_embeddings_file, processor, model, device)
# Out:
# Processing Captions: 100%|██████████| 9933/9933 [02:21<00:00, 70.31it/s]
# 2025-02-14 09:58:58,052 - INFO - All caption embeddings saved in: /content/flickr30k_dataset/30k_pretrain_caption_embeddings.pt

# %%
def compute_similarity_and_accuracy(image_embeddings_list, captions_embeddings_list, image_embeddings_dict, captions_embeddings_dict):
    """
    Compute similarity between image and caption embeddings and calculate accuracy.

    Args:
        image_embeddings_list (list): List of image embeddings as tensors.
        captions_embeddings_list (list): List of caption embeddings as tensors.
        image_embeddings_dict (dict): Mapping from image embeddings to filenames.
        captions_embeddings_dict (dict): Mapping from caption embeddings to filenames.

    Returns:
        float: Accuracy percentage.
    """
    # Check if the lists are empty
    if len(image_embeddings_list) == 0 or len(captions_embeddings_list) == 0:
        logger.error("Embedding lists are empty. Ensure embeddings are loaded correctly.")
        return 0.0

    try:
        # Convert lists of embeddings to numpy arrays
        image_embeddings_matrix = np.vstack(image_embeddings_list)
        captions_embeddings_matrix = np.vstack(captions_embeddings_list)

        # Normalize the embeddings to unit vectors
        image_embeddings_matrix_normalized = image_embeddings_matrix / np.linalg.norm(image_embeddings_matrix, axis=1, keepdims=True)
        captions_embeddings_matrix_normalized = captions_embeddings_matrix / np.linalg.norm(captions_embeddings_matrix, axis=1, keepdims=True)

        # Compute the cosine similarity matrix
        similarity_matrix = np.dot(image_embeddings_matrix_normalized, captions_embeddings_matrix_normalized.T)
        logger.info(f"Similarity matrix shape: {similarity_matrix.shape}")

        # Find the index of the highest similarity for each image embedding
        max_similarity_ids = np.argmax(similarity_matrix, axis=1)
        logger.info(f"Max similarity indices: {max_similarity_ids}")
        if max_id >= len(captions_embeddings_dict) or idx >= len(image_embeddings_dict):
          logger.error(f"Index mismatch: image index {idx} or caption index {max_id} not found in dictionaries.")


        # Log lengths of embeddings and dictionaries for debugging
        logger.info(f"Length of image embeddings list: {len(image_embeddings_list)}")
        logger.info(f"Length of image embeddings dictionary: {len(image_embeddings_dict)}")

        # Calculate accuracy by comparing filenames directly
        accuracy_list = []
        for idx, max_id in enumerate(max_similarity_ids):
            # Get filenames from the dictionaries using the indices
            image_filename = image_embeddings_dict[idx]  # Get image filename by index
            caption_filename = captions_embeddings_dict[max_id]  # Get caption filename by index

            # Compare the filenames to check if they match
            accuracy_list.append(1 if image_filename == caption_filename else 0)

        # Compute and return the accuracy
        accuracy = np.mean(accuracy_list) * 100 if accuracy_list else 0.0
        logger.info(f"Accuracy: {accuracy:.2f}%")
        return accuracy

    except Exception as e:
        logger.error(f"Error in computing similarity and accuracy: {e}")
        return 0.0

# %%
def load_embeddings(embeddings_file):
    """
    Load embeddings and corresponding filenames from a single file.

    Args:
        embeddings_file (str): Path to the embeddings file.

    Returns:
        filenames (list): List of filenames.
        embeddings (Tensor): Tensor containing all embeddings.
        embeddings_dict (dict): Mapping from embeddings to filenames.
    """
    #embeddings = torch.load(embeddings_file)
    embeddings = torch.load(embeddings_file, weights_only=True)

    filenames_file = embeddings_file.replace('.pt', '_filenames.json')
    with open(filenames_file, 'r') as f:
        filenames = json.load(f)

    #embeddings_dict = {str(emb.tolist()): filename for emb, filename in zip(embeddings, filenames)}

    embeddings_dict = {}
    for emb, filename in zip(embeddings, filenames):
      key = str(filename)  # Use filename as key
      if key in embeddings_dict:
        embeddings_dict[key].append(emb.tolist())  # Append to list
      else:
        embeddings_dict[key] = [emb.tolist()]  # Create a list for multiple embeddings

    return filenames, embeddings, embeddings_dict

# %%
# Load image and caption embeddings
image_filenames_list, image_embeddings_list, image_embeddings_dict = load_embeddings(images_embeddings_file)
captions_filenames_list, captions_embeddings_list, captions_embeddings_dict = load_embeddings(captions_embeddings_file)
#logger.info(f"Loaded {len(image_embeddings_list)} image embeddings and {len(captions_embeddings_list)} caption embeddings.")
#accuracy = compute_similarity_and_accuracy(image_embeddings_list, captions_embeddings_list, image_embeddings_dict, captions_embeddings_dict)
#logger.info(f'Accuracy: {accuracy:.2f}%')

# %%
# Function to get embeddings for text using CLIP
def get_query_embedding(query_string):
    inputs = processor(text=query_string, return_tensors="pt", padding=True, truncation=True).to(device)
    with torch.no_grad():
        text_embedding = model.get_text_features(**inputs)
    return text_embedding / torch.norm(text_embedding)  # Normalize

# %%
# Function to get embeddings for Image using CLIP
def get_image_embedding(image_path):
    image = Image.open(image_path).convert("RGB")  # Ensure image is in RGB mode
    inputs = processor(images=image, return_tensors="pt").to(device)
    with torch.no_grad():
        image_embedding = model.get_image_features(**inputs)
    return image_embedding / torch.norm(image_embedding)

# %%
# Function to display top images with their ranks and scores
def display_images(top_images, images_path):
    # Create a figure with enough subplots to display images
    num_images = len(top_images)
    cols = 3  # You can change this based on how many images you want in a row
    rows = (num_images + cols - 1) // cols  # Calculate rows needed based on the number of images

    plt.figure(figsize=(20, 3 * rows))  # Adjust the size of the figure based on number of images

    for i, img_info in enumerate(top_images):
        # Ensure the filename has the .jpg extension (if not, add it)
        filename = img_info['item']

        if not filename.endswith('.jpg'):
          filename = filename.replace('.pt', '.jpg')
        # Path to the image file
        image_path = os.path.join(images_path, filename)

        # Open the image
        try:
            img = Image.open(image_path)
            ax = plt.subplot(rows, cols, i + 1)
            ax.imshow(img)
            ax.set_title(f"Rank {i + 1}: {filename} (Score: {img_info['score']:.4f})")
            ax.axis('off')
        except Exception as e:
            logger.error(f"Error loading image {filename}: {e}")

    plt.tight_layout()
    plt.show()

# %%
def display_iteam(image_path):
  img = Image.open(image_path)
  plt.figure(figsize=(2, 2))
  plt.imshow(img)
  plt.axis("off")  # Hide axes
  plt.show()

# %%
def search_top_matches(query_input, embeddings_list, items_list, top_n, get_embedding_fn):
    """
    Generic function to search for top N matches based on cosine similarity.

    Parameters:
    - query_input (str or image_path): The input query (text caption or image path).
    - embeddings_list (list of Tensors): List of stored embeddings (image or caption).
    - items_list (list): List of items (image filenames or text captions).
    - top_n (int): Number of top matches to return.
    - get_embedding_fn (function): Function to get the embedding (e.g., get_image_embedding or get_query_embedding).

    Returns:
    - List of dictionaries with "item" and "score" keys.
    """
    # Get the query embedding and normalize it
    query_embedding = get_embedding_fn(query_input).to(device)
    query_embedding = query_embedding / torch.norm(query_embedding)

    # Convert list of embeddings into a tensor for batch processing
    embeddings_list = [torch.tensor(embedding) if not isinstance(embedding, torch.Tensor) else embedding for embedding in embeddings_list]
    embeddings_tensor = torch.stack(embeddings_list).to(device)

    # Normalize all stored embeddings
    embeddings_tensor = embeddings_tensor / torch.norm(embeddings_tensor, dim=1, keepdim=True)

    # Compute cosine similarity in batch
    similarities = torch.matmul(embeddings_tensor, query_embedding.T).squeeze()

    # Get indices of top N matches
    #top_indices = torch.argsort(similarities, descending=True)[:top_n]

    # Retrieve top matching items
    #top_matches = [{"item": items_list[i], "score": similarities[i].item()} for i in top_indices]

    # Get indices of top N+1 matches (to account for removing query itself)
    top_indices = torch.argsort(similarities, descending=True)

    # Retrieve top matching items, excluding the query image itself and scores >= 1
    top_matches = []
    query_index = items_list.index(query_input) if query_input in items_list else None  # Find query index if it exists

    for i in top_indices:
        if len(top_matches) >= top_n:
            break  # Stop once we have enough matches
        if query_index is not None and i == query_index:
            continue  # Skip the query image itself
        if similarities[i].item() >= 1:
            continue  # Skip matches with scores >= 1

        top_matches.append({"item": items_list[i], "score": similarities[i].item()})


    return top_matches

# %%
top_n = 1

# %%
#Search for the top images matching a given caption.
logger.info("Text---to---Image")
caption = "A little girl is swinging in a baby swing on the playground"
logger.info(f"{caption}")
logger.info(f"Top {top_n} images:")
top_images = search_top_matches(caption, image_embeddings_list, image_filenames_list,top_n,get_query_embedding)
# Print top 5 results
for idx, img in enumerate(top_images):
    logger.info(f"Rank {idx + 1}: {img['item']} (Score: {img['score']:.4f})")
display_images(top_images, images_path)
# Out:
# 2025-02-13 19:03:20,116 - INFO - Text---to---Image
# 2025-02-13 19:03:20,118 - INFO - A little girl is swinging in a baby swing on the playground
# 2025-02-13 19:03:20,119 - INFO - Top 1 images:
# 2025-02-13 19:03:20,166 - INFO - Rank 1: 2436081047_bca044c1d3.jpg (Score: 0.3380)

# %%
def captionToImage(caption):
  caption = "A little girl is swinging in a baby swing on the playground"
  logger.info(f"{caption}")
  logger.info(f"Top {top_n} images:")
  top_images = search_top_matches(caption, image_embeddings_list, image_filenames_list,top_n,get_query_embedding)
  image_name=top_images[0]['item']
  return image_name

# %%
image_name=captionToImage("A little girl is swinging in a baby swing on the playground")
image_full_path = os.path.join(images_path, image_name)
display_iteam(image_full_path)
# Out:
# 2025-02-14 10:02:12,474 - INFO - A little girl is swinging in a baby swing on the playground
# 2025-02-14 10:02:12,476 - INFO - Top 1 images:

# %%
# #Search for the top images matching a given image.
logger.info("Image---to---Image")
image_name ="1000523639.jpg"
image_path = os.path.join(images_path, image_name)
display_iteam(image_path)
logger.info(f"Top {top_n} images:")
top_images = search_top_matches(image_path, image_embeddings_list, image_filenames_list,top_n,get_image_embedding)
# Print top 5 results
for idx, img in enumerate(top_images):
    logger.info(f"Rank {idx + 1}: {img['item']} (Score: {img['score']:.4f})")
# Set path to images
display_images(top_images, images_path)
# Out:
# 2025-02-14 10:02:59,755 - INFO - Image---to---Image
# 2025-02-14 10:02:59,801 - INFO - Top 1 images:
# 2025-02-14 10:02:59,944 - INFO - Rank 1: 4508668804.jpg (Score: 0.7670)

# %%
dataframe = pd.read_csv("/content/flickr8k_dataset/captions.csv")
dataframe.head()
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption  caption_number  id
# 0  A child in a pink dress is climbing up a set o...               0   0
# 1              A girl going into a wooden building .               1   0
# 2   A little girl climbing into a wooden playhouse .               2   0
# 3  A little girl climbing the stairs to her playh...               3   0
# 4  A little girl in a pink dress going into a woo...               4   0

# %%
#Search for the top captions matching a given caption.
logger.info("Caption---to---Captions")
query_string = "A little girl is swinging in a baby swing on the playground ."
logger.info(f"{query_string}")
logger.info(f"Top {top_n} Captions:")
top_captions = search_top_matches(query_string,captions_embeddings_list,captions_filenames_list,top_n,get_query_embedding)
# Print top 5 results
#print(dataframe['caption'])
for i, item in enumerate(top_captions):
    caption=item['item']
    base_name, number = caption.rsplit('_', 1)
    match = dataframe[(dataframe['image'] == base_name) & (dataframe['caption_number'] == int(number))]
    # Return the 'caption' column of the matched row
    caption_text = match['caption'].iloc[0] if not match.empty else None
    print(caption_text)
# Out:
# 2025-02-14 10:03:11,349 - INFO - Caption---to---Captions
# 2025-02-14 10:03:11,351 - INFO - A little girl is swinging in a baby swing on the playground .
# 2025-02-14 10:03:11,353 - INFO - Top 1 Captions:
#  a boy with red soled shoes is playing on a swing .

# %%
#Search for the top captions matching a given image.
logger.info("Image---to---Captions")
image_name = "1000523639.jpg"
image_path = os.path.join(images_path, image_name)
display_iteam(image_path)
logger.info(f"Top {top_n} images:")
top_captions = search_top_matches(image_path,captions_embeddings_list,captions_filenames_list,top_n,get_image_embedding)
# Print top 5 results
for i, item in enumerate(top_captions):
    caption=item['item']
    caption=caption.replace('.jpg_', '.jpg#').replace('.pt', '')
    logger.info(f"{i+1}.{captions[caption]}, Score: {item['score']:.4f}")
# Out:
# 2025-02-14 10:03:29,602 - INFO - Image---to---Captions
# 2025-02-14 10:03:29,640 - INFO - Top 1 images:
# 2025-02-14 10:03:31,665 - INFO - 1.[], Score: 0.3179

# %%
def imageToCaptions(image_name):
  logger.info("Image---to---Captions")
  #image_name="36979.jpg"
  image_path = os.path.join(images_path, image_name)
  display_iteam(image_path)
  logger.info(f"Top {top_n} images:")
  top_captions = search_top_matches(image_path,captions_embeddings_list,captions_filenames_list,top_n,get_image_embedding)
  caption = top_captions[0]['item']
  return caption

# %%
image_name = "1000523639.jpg"
caption=imageToCaptions(image_name)
print(caption)
# Out:
# 2025-02-14 10:04:15,649 - INFO - Image---to---Captions
# 2025-02-14 10:04:15,685 - INFO - Top 1 images:
# 6269296633.jpg_2

# %%
# !zip -r flickr30k_dataset.zip /content/flickr30k_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/flickr30k_dataset/flickr30k_images/4725662892.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3556039987.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/558161347.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4441842421.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2925163942.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4441594448.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/254478202.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/495041730.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2934837034.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5491402223.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4869523413.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3972572766.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3054192830.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/19610188.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7188003.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4328448107.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3044359043.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2448172829.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4848644668.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/454691853.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4337739734.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/355869840.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4913618585.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/976392326.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5762196405.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/5332049234.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/189570539.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/294443417.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4872513153.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/484093882.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4569656361.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2215737172.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1534613774.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7712229454.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4467431522.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1238849490.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6553168529.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2480333312.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2142414731.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/49703118.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2519594430.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5954939506.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2471184383.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2354007039.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3019864782.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6907789234.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4840632989.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/437827172.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/491600485.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5562975921.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/38110161.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3326376344.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/200778857.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3926139835.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3673069138.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2856456013.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/599235529.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6907187997.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7011012597.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/499340051.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4952155171.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/3213954789.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2824004868.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/253320564.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4792160184.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4846324908.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/7680212664.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/640289559.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7308951892.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/127875146.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4785852807.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3335885203.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3276448136.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4518796612.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/174466741.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7171533329.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4145725901.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2525232298.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2603125422.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4690243307.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/2022443431.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2573141440.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3957765471.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4804599874.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/86542183.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3733747387.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3577309234.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6502187283.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/273945661.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3236447445.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3225880532.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4553696388.jpg (deflated 10%)
#   adding: content/flickr30k_dataset/flickr30k_images/4663464371.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/7059676827.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4901197698.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/1800778962.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3692055291.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2470486377.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2899089320.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/294074951.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3561639055.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/8111420340.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/7312171080.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4708658738.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/4591228112.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2675685200.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1368108583.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/5419038647.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3380929595.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/250406927.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4677521690.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7062794595.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4985704.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2326664830.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3215847501.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2778198363.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4740643779.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2085284792.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2200875336.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/3831843450.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/109202756.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/118854260.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/1507563902.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4674781735.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/1472249944.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/100652400.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3969219773.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3670184928.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4699396026.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/237277765.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/532396029.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3638783120.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3293945284.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2594336381.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4834128818.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5293561716.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3501083764.jpg (deflated 15%)
#   adding: content/flickr30k_dataset/flickr30k_images/5265298056.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2288988751.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3687996279.jpg (deflated 12%)
#   adding: content/flickr30k_dataset/flickr30k_images/2245348304.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6229823951.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/57078880.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2366306683.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/135613639.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4552731904.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/165984091.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2231052760.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/7772746168.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3760010229.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3653062245.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/387697067.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/102575576.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6781418332.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4049532274.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2095845115.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3869207554.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2822148499.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4825747859.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/2310336052.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4659788392.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/528726853.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2063272936.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/428911994.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6155176.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/4738240252.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3983874347.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/2907088408.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5225304863.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/2474115124.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3259330901.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5855641283.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/5491874786.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/620595746.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2900560501.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/207344485.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6421917743.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2395360530.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4980845265.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4691728367.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/2721786210.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1720835468.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2341904462.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7513059830.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2799871904.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6953548178.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3311659972.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2196107384.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/529198549.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4643839937.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/526995387.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2299867034.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2943557287.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3688343105.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4782447844.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/872622575.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2009636597.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2772831016.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2308978137.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/7631372276.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1096097967.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3855962376.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/2107837987.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4937650592.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/2760716468.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4849249884.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/2867968184.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7702108102.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/5876512276.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2754898893.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2422233191.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/754852108.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/242558556.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3053785363.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7186836768.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7725132206.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3508637029.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4082185154.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3653462288.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4866267667.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/186890601.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/488089932.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7650753866.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3402638444.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2888808511.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4820830153.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2995173839.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/510046396.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3252985078.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4329198220.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2786115354.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4758584005.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/43400872.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3123770450.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/741227062.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4760325851.jpg (deflated 11%)
#   adding: content/flickr30k_dataset/flickr30k_images/2796801478.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4209480025.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3288928346.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3816820298.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/4830075359.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4463772847.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/6053012389.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/1089059626.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/353180303.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4161829222.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3378167937.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/110820212.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2941340816.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/96669857.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4474053436.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/2454054454.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/189233427.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2503091968.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4366908113.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/4270956712.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3720930427.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7591663030.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4122645918.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3435653630.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2423254262.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/58363928.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2273105617.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2661567396.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4201060050.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/302740416.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/442987551.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3377383984.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4004035933.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2544134113.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3506454111.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4772268645.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4716605063.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/2788933694.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4826353878.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/6046474576.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4532756721.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2955813024.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/319076839.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3454754632.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2266901263.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2413495734.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/89353191.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2087423271.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4018622493.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2796930150.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3296584432.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/299078301.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4897085764.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4564193650.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/10637120.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3280052365.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/524698457.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/8116539330.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2796525620.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2564663851.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4636277239.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3203908917.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2866093652.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2473271288.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4898817738.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2077063153.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4335121319.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3155279929.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3389707399.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/150598969.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5572655622.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2001867714.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2747957935.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4731681353.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2898690285.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2481367956.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/463554115.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4555412480.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2230140329.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2664091531.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4877885745.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7397183064.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/6335241.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5836131322.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/4850906257.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3177799416.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3420260768.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3242354561.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/73636277.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2363918218.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/339822505.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3344226994.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4286588375.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3221815947.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4626046174.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/3602437310.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7249187716.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6530902779.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4734385389.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3393274529.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3106257008.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4436634122.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4853180757.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/7203576450.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4668422696.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5715657613.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2595501969.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2300168895.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1295747912.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/763577068.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4951538722.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/47325915.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3355683198.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1463864223.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/174385510.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4296835667.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/3331009729.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5585791618.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/2618538137.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/370614244.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4895977486.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/4588980563.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3576387257.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3695064885.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2537021135.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3701878677.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2302816463.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4169121436.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/4649915901.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4948635454.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2366166967.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/371121323.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/389643437.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/402978771.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/51565199.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6925158300.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3601803640.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4625651551.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/4701188650.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/4485090958.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2924884815.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6150843883.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/1289953720.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4660152902.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4588654711.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/4563782751.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/277928620.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2359499627.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4971946200.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3669056658.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4977405533.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/4756089637.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/2206284983.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3799984714.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4889307357.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/1207159468.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/1797436026.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4138721052.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/7517274630.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1413647425.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3489014985.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3203707977.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3500218173.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3093742683.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4629625465.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4872490297.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5077873899.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/2924870944.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4134335534.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3548421323.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2441313372.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/50030244.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/400562847.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3656104088.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/483286214.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3395865342.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1961696686.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3324056835.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1348517063.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4829255593.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/3319489465.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3440387274.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2573810556.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/1527333441.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3439390288.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6223093296.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6526219567.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3843366278.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5923507305.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3410629379.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/200778628.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2533010184.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/5447361965.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/4658745957.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/5835573414.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/2681215810.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4980391949.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/255091927.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/120545126.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/388386075.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6826571981.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2774705720.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/104285082.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/274646416.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5123125004.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3681967973.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/542605701.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/505929313.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3277834387.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4979680901.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/372770231.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2148680620.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3851686271.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1072153132.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/85306246.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/133661473.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2234681386.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3486831654.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/2656252763.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2624979508.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/205520729.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/747242766.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1489471156.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4774444362.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/3438060110.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/32184285.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2508313118.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/957230475.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4560046189.jpg (deflated 9%)
#   adding: content/flickr30k_dataset/flickr30k_images/5084604998.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6662272621.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/523692399.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2508511510.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2645723249.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2159526836.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2987232840.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1394756978.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1087168168.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2985439112.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2752329719.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/151177193.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1481393167.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2950393735.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2504683345.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4508508210.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2934573544.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3522495606.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4669711863.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4465873365.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1433924222.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6075614739.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/447686870.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/8205105666.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/13615892.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3419436117.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4725650100.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/241596333.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4883101538.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3341930221.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3700554247.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/4509270396.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/7196226216.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4546261932.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7012109893.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/137431037.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5469569530.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4098382666.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7343282792.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/160417285.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1250745375.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/89404014.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/319851847.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/424779662.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/8177393638.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/6269296633.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/470272588.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4804569802.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/6235432058.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/457945610.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/170007535.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/145053276.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/45312111.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3326024473.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2127166904.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2800934095.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/137431020.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2649406158.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3678885320.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6845811278.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4979928175.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/150411291.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/136639119.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4701498512.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/3391924827.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4946160196.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2252036322.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4186516481.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6336028231.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4625729459.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/2245914678.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7594999748.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3511890331.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3406116788.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1245022983.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3005393426.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4222067827.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/75718482.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3809012603.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2636930201.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2560981288.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2597873827.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4726725769.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2685727511.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2502007071.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3820465361.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/2320742338.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4855964619.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3438142614.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4618885426.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/4715755037.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3527572464.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2704934519.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2205336881.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4170746161.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/4652665785.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/3753777206.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4878257186.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/3523851105.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1609454863.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4932970587.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/627714170.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/515165357.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4675748463.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2493469969.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6302283809.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/7654089948.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3304712466.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4553464209.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/6917596231.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4080351447.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2588456052.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4003920724.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3902127239.jpg (deflated 12%)
#   adding: content/flickr30k_dataset/flickr30k_images/3353036763.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1076503761.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4141011708.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/2844202978.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4230694069.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6104320982.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/4964794183.jpg (deflated 4%)
# ...
#   adding: content/flickr30k_dataset/flickr30k_images/2551632823.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4604103482.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3108542351.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2183227136.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2907244809.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/86120845.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/464506846.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6021205363.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4005756399.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3262475923.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4731712149.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3563668905.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2780087302.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2800004913.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4686806018.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2371545499.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2154062056.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2402793046.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/165634708.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3793793899.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2687134043.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4770745669.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4948224114.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2178064851.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2636668640.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/611349356.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2335428699.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/469969326.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4768540307.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/172097782.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4726972254.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/2668179897.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2699125097.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7729204508.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3151492269.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4628050549.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/269898428.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3232802293.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3042405316.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4878089623.jpg (deflated 12%)
#   adding: content/flickr30k_dataset/flickr30k_images/3010330230.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/85707684.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3472703856.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4615498560.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4717130803.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3275627207.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3274758325.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2750832671.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/23445819.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3381392182.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2072040759.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4694000518.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/3325584169.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4362204688.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/4449368922.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4433634883.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/3377117696.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3549614763.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3035785330.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4838244073.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5501939468.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/446243490.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4573388475.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/524036004.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2686470807.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4944827656.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2970827076.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6291644661.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4710230329.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6923722761.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2715064456.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2155533127.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3658016590.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/252054933.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/367740349.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2808870080.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5006148987.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/2074642785.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4669745123.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/3586834355.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3020785883.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3774622914.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2307118114.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2853451727.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2853205396.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2300229745.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6319098573.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/549520317.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2855417531.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/48296039.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2788652511.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4982800224.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3731803474.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3255482333.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/5073552229.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/435908408.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2132295466.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/303102907.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2997939824.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5652699228.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/164969525.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/565605894.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2973356661.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4885212423.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/5589601689.jpg (deflated 12%)
#   adding: content/flickr30k_dataset/flickr30k_images/256085101.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2242676214.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3132006797.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4829026306.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/912402498.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2394237885.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/12118309.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2866686547.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2509912399.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5214344526.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4789495327.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/3654402537.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/426375654.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2482588693.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6892084963.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2089350172.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6369706433.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4196910882.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/4552266067.jpg (deflated 6%)
#   adding: content/flickr30k_dataset/flickr30k_images/3349258288.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/4852829439.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4731694958.jpg (deflated 5%)
#   adding: content/flickr30k_dataset/flickr30k_images/3510218982.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/8063954905.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/2585141045.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/264346756.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/56659639.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4445453116.jpg (deflated 13%)
#   adding: content/flickr30k_dataset/flickr30k_images/4514082925.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/7777767632.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/211277478.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3349309109.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2409312675.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5851970989.jpg (deflated 8%)
#   adding: content/flickr30k_dataset/flickr30k_images/408474778.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2452238877.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/1333788342.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3290105461.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/6445655263.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2931695159.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4521610802.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5973476404.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4853218641.jpg (deflated 4%)
#   adding: content/flickr30k_dataset/flickr30k_images/565490650.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4716376540.jpg (deflated 2%)
#   adding: content/flickr30k_dataset/flickr30k_images/228866972.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2854207034.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3944169186.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/24651801.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/36979.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/165764051.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2929188436.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4877883053.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/1161159603.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/320593325.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/3469609037.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/45934206.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2751721665.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4441088009.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4623188792.jpg (deflated 3%)
#   adding: content/flickr30k_dataset/flickr30k_images/2128119486.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5590283636.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/365291944.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/152881593.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2249094622.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/458730998.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2654018684.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/154653766.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/539061478.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2570365455.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2506892928.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3159328476.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/72010195.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/378434971.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4868008430.jpg (deflated 7%)
#   adding: content/flickr30k_dataset/flickr30k_images/3057862887.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/7596563022.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/5843625835.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3273892996.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/2834032170.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3791132794.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/8378599.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/3826376965.jpg (deflated 1%)
#   adding: content/flickr30k_dataset/flickr30k_images/1803631090.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/4571649296.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/541537091.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/flickr30k_images/219288082.jpg (deflated 0%)
#   adding: content/flickr30k_dataset/captions.csv (deflated 73%)
#   adding: content/flickr30k_dataset/captions.txt (deflated 73%)
#   adding: content/flickr30k_dataset/30k_pretrain_image_embeddings.pt (deflated 7%)
#   adding: content/flickr30k_dataset/30k_pretrain_caption_embeddings.pt (deflated 7%)

# %% [markdown]
# # New Section
